# %%
import pandas as pd
import numpy as np
import pymongo
import json

# %%
client = pymongo.MongoClient("mongodb+srv://shiv_test:test@cluster0.xzzdmgf.mongodb.net/test")

# %%
df = pd.read_csv('Product.csv')

# %%
df.shape
# Out:
# (480, 5)

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'Unnamed: 0': 0,
#   'name': '"Twelve Blends" Spice Box With 12 Containers & Spoon In Sheesham Wood',
#   'price': 1340,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/EL-005-614_A_400x.jpg'},
#  {'Unnamed: 0': 1,
#   'name': 'Sheesham Wood Square Spice Box With Spoon (9 Compartments)',
#   'price': 993,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/EL-005-058_A_400x.jpg'},
#  {'Unnamed: 0': 2,
#   'name': 'Sheesham Wood Square Spice Box With Spoon (9 Containers)',
#   'price': 1199,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/el-005-153_a_3_400x.jpg'},
#  {'Unnamed: 0': 3,
#   'name': 'Sheesham Wood Circular Spice Box With Floral Work (9 Compartments)',
#   'price': 3299,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/65_400x.png'},
#  {'Unnamed: 0': 4,
# ...

# %%
for i in range(480):
     key = data[i]
     del key['Unnamed: 0']

data
# Out:
# [{'name': '"Twelve Blends" Spice Box With 12 Containers & Spoon In Sheesham Wood',
#   'price': 1340,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/EL-005-614_A_400x.jpg'},
#  {'name': 'Sheesham Wood Square Spice Box With Spoon (9 Compartments)',
#   'price': 993,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/EL-005-058_A_400x.jpg'},
#  {'name': 'Sheesham Wood Square Spice Box With Spoon (9 Containers)',
#   'price': 1199,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/el-005-153_a_3_400x.jpg'},
#  {'name': 'Sheesham Wood Circular Spice Box With Floral Work (9 Compartments)',
#   'price': 3299,
#   'category': 'spice-boxes',
#   'image_link': 'cdn.shopify.com/s/files/1/0030/9759/1872/products/65_400x.png'},
#  {'name': "'Floral-Etched' Handcrafted Spice Box In Brass With Spoon (7 Containers, 100 ML)",
#   'price': 3208,
# ...

# %%
db = client["craft"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-ujehkm0-shard-00-01.xzzdmgf.mongodb.net:27017', 'ac-ujehkm0-shard-00-02.xzzdmgf.mongodb.net:27017', 'ac-ujehkm0-shard-00-00.xzzdmgf.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-l3nfmk-shard-0', tls=True), 'craft')

# %%
db.products.insert_many(data)
