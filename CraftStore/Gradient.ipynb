# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples = 4 , n_features=1 , n_informative=1 , n_targets=1 ,noise=80 , random_state=13)

# %%
import matplotlib.pyplot as plt

plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg  = LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
y_pred =  reg.predict(X)

# %%
plt.scatter(X,y)
plt.plot(X,y_pred, color = 'blue')

# %%
m = 78.35063668
y_predict = ((m*X) + 0 ).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,y_pred, color = 'blue')
plt.plot(X,y_predict, color = 'blue')

# %%
b = 0 
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -209.27706274458984

# %%
lr = 0.1
step_size = loss_slope*lr

# %%
b = b - step_size
b
# Out:
# 119.28792576441622

# %%
y_predict_1 = ((m*X) + b ).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,y_pred, color = 'red')
plt.plot(X,y_predict, color = 'blue')
plt.plot(X,y_predict_1, color = 'yellow')

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
step_size = loss_slope*lr
b = b - step_size
y_predict_2 = ((m*X) + b ).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,y_pred, color = 'red')
plt.plot(X,y_predict, color = 'blue')
plt.plot(X,y_predict_1, color = 'yellow')
plt.plot(X,y_predict_2, color = 'yellow')

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
step_size = loss_slope*lr
b = b - step_size

y_predict_3 = ((m*X) + b ).reshape(4)
b
# Out:
# 26.165593053820697

# %%
plt.scatter(X,y)
plt.plot(X,y_pred, color = 'red')
plt.plot(X,y_predict, color = 'blue')
plt.plot(X,y_predict_1, color = 'yellow')
plt.plot(X,y_predict_2, color = 'yellow')
plt.plot(X,y_predict_3, color = 'black')

# %%
b = -100
epoches = 10
lr = 0.1

for i in range(epoches):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b)
    step_size = loss_slope*lr
    b = b - step_size
    y_predict = ((m*X) + b ).reshape(4)
    plt.plot(X,y_predict ,color = 'blue')

plt.scatter(X,y)
